# %% [markdown]
# ### Lojistik Regresyon İçin Gradient Descent
#
# * ![image.png](attachment:image.png)
#
# * Yine bir cost fonksiyonumuz vardır. hxi'ler tahmin edilen değerleri, yi'ler gerçek değerleri ifade etmektedir. Bu problem için cost fonksiyonumuz diğer ifadesiyle lost fonksiyonumuz loglos ifadesidir.
#
# * ![image-2.png](attachment:image-2.png)
#
# * Diyelim ki elimizde 100 tane gözlem birimimiz var. Herbir gözlem birimi tek tek gezilerek buradaki hesaplama işlemi gerçekleştirilecek. Diyelim ki 1.gözleme gittik.
#
# * ![image-3.png](attachment:image-3.png)
#
# *
# *
# *
#
# * ![image-4.png](attachment:image-4.png)
#
# * Bu işlemler sonucu lost'un küçük olması beklenir.
#
# *  DİKKAT : Belirli bir ağırlık kombinasyonu ile bu sınıflandırma işlemi gerçekleştirildiğinde sınıflandırmaya girerken ifade etmiştik ki her zaman 1 sınıfına ait olma olasılığı hesaplanır. Dolayısıyla bu 1 sınıfına ait olma olasılığı ve 0 sınıfına ait olma olasılığı değerlendirilerek herbir sınıf için kayıp hesaplanır. Ortalaması alınarak ortalama kayıp/lost bulunmuş olunur.
#
# * Bir iterasyon ile bu hesaplandı diyelim. Gradient descent burada nasıl devreye girer? Türevlenebilen ve bir parametreyle şekillenen bir fonksiyonu ilglili parametreye göre kısmi türevi alındığında bu ilgili kısmi türev belirli bir öğrenme oranı ile çarpılarak ilgili parametrenin eski değerleriyle işleme sokulur ve bu parametrenin değeri güncellenir. Bu güncellemeler esnasında hatanın düşmesi gözlemlenir. Bunun matematiksel ifadesi aşağıdaki gibidir:
#
# * ![image-5.png](attachment:image-5.png)
