# %% [markdown]
# ### Classification Threshold
#
# * ![image.png](attachment:image.png)
#
# * ![image-2.png](attachment:image-2.png)
#
# * DİKKAT : Kullandığımız fonksiyonlarda bu olasılık değerlerini görmesek de arka tarafta her zaman 1 sınıfına ait olma olasılığı olur. Bir model kurulduğunda ilgili churn sınıfına dahil olma olasılıklarını hesaplarız.
#
# * ![image-3.png](attachment:image-3.png)
#
# * ![image-4.png](attachment:image-4.png)
#
# * ![image-5.png](attachment:image-5.png)
#
# * ![image-6.png](attachment:image-6.png)
#
# * Doğru eşleşen ikililere bakmalıyız!!!
#
# * ![image-7.png](attachment:image-7.png)
#
# * ![image-8.png](attachment:image-8.png)
#
# * Eşik değerler değiştikçe accuracy dolayısıyla bütün istatistikler değişiyor olacaktır. Eşik değeri değişmesine göre nihai sınıf tahminlerimiz değişiyor. O zaman öyle bir hesaplama yapılmalı ki eşik değer değişimleri de göz önünde bulundurularak bir matematiksel ifade ile bunu hesaplayalım. Bunun için ROC Curve Yöntemi kullanılır. Başka bir sınıflandırma probleminde başarı değerlendirme metriğidir.
