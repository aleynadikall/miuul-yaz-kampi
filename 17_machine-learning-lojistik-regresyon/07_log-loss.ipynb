# %% [markdown]
# ### LOG Loss
#
# * DİKKAT : LOG Loss ifadesi bir başarı metriğidir. Bu başarı metriğini hem modelin başarısı için hem de optimizasyon yapmak için gerek hiperparametrelerde gerek ağırlıklarda iterasyon sayısı açısından diğer bazı olası sınıflandırma makine öğrenmesi algoritmalarında hiperparametreleri bulmak adına optimize etmek için kullanacağımız fonksiyondur. Aşağıdaki metrik cross entropy metriğidir.
#
# * ![image.png](attachment:image.png)
#
# * DİKKAT : Entropy fizik, kimya, matematik, istatistik gibi birçok farklı alanda kullanılan bir ifadedir. Entropy şu anda bizim ilgilendiğimiz kısım açısından ne kadar düşük o kadar iyi anlamına gelir. Entropy çeşitliliktir. Entropy ne kadar yüksekse o kadar çeşitlilik vardır. Entropy büyükse varyans vardır. Mesela diyelim ki 1 0 1 0 şeklinde ve 1 1 1 1 şeklinde sayılarımız olsun. Hangisinin entropysi daha yüksektir diye sorulduğunda 1 0 1 0 bölümünün entropysi çeşitlilik fazla olduğu için daha yüksektir. Bu çeşitlilik ya da bilgi ya da daha az bilgi, daha çok bilgi konusunu yapmış olduğumuz tahminler ile gerçek değerler arasındaki durumu değerlendirmek için kullanıyor olacağız.
#
# * Diyelim ki elimizde şöyle bir veri seti olsun:
#
# * ![image-2.png](attachment:image-2.png)
# *
# *
# * ![image-3.png](attachment:image-3.png)
