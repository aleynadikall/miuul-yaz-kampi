# %% [markdown]
# ### Parametlerin Tahmin Edilmesi (Ağırlıkların / Katsayıların / Tahmincilerin Bulunması)
#
# * Bize en küçük hatayı verecek olan sabiti ve ağırlığı bulmak istiyoruz.
#
# * ![image.png](attachment:image.png)
#
# * cost ifadesi = MSE ifadesi demiştik. Amacımız belirli w ve b kombinasyonlarına karşılık hatanın ne olabileceğini gözlemleyip bu sabit ve ağırlığı optimum değerleriyle (MSE'yi/hatayı en küçük verecek şekilde) seçmeye çalışmaktır. Peki bunu nasıl bulacağız?
#
# * DİKKAT : Bu ağırlıkları bulmanın bir yolu analitik bir çözüm olan normal denklemler yöntemidir. En küçük kareler yöntemi olarak da geçer. Bu yöntem analitik ve öatris formunda bir çözümdür. Türeve dayalı bir çözümdür. Bu yöntem kullanıldığında ortaya çıkacak olan formülasyon üzerinde analitik yorumlar yapılabilir. Neden sonuç bağlamında yorumlar yapılabilir. Eğer elimizde tek bir değişken varsa yani bir bağımlı bir bağımsız değişken varsa bu durumda iki parametreye göre ayrı ayrı kısmi türevler alınıp sıfıra eşitlenir ve bulunması gereken matematiksel ifade aşağıdaki gibi olur:
#
# * ![image-2.png](attachment:image-2.png)
# * SSE (Sum of Square Error) diye bir şey geldi. b0 b1 gibi şeyler var. Buralardan korkmuyoruz artık regresyon problemlerinde sınıflandırma problemlerinde bir dara mı düştük hemen aklımıza MSE formülünü getirmeliyiz. Gerçek değerlerle tahmin edilen değerlerin farklarına ilişkin bir şeyler aramalıyız ki bu şekilde işin içinden çıkabiliyor olacağız.
#
# * scikitlearn kütüphanesinde normal denklemler yöntemi kullanılır.
# * Çok değişken varsa:
#
# * ![image-3.png](attachment:image-3.png)
#
# * Genel olarak;
#
# * ![image-4.png](attachment:image-4.png)
#
# * X de bağımsız değişkenlerin Y de bağımlı değişkenin değeri vardır. -1 tersi işlemini ifade eder. T transpozu ifade eder.
#
# * DİKKAT : Buradaki -1 ifadesi yani tersini alma ifadesi bizim için önemli bir yere sahip çünkü gözlem ve değişken sayısı çok fazla arttığında bu matrisin tersini alma işlemi zorlaşmakta ve gradient descent gibi optimizasyona dayalı yöntemlerin ihtiyacı kendisini hissettirmeye başlamaktadır. Lisans üstü bir Phd sorusu olabilecek bir sorunun yanıtıdır bu. Neden istatistikte yaygınca kullanılan normal denklemler yöntemi değil de gradient descent yöntemi kullanalım ki sorusunun yanıtlarından birisidir. Çünkü çoklu doğrusal regresyon probleminde normal denklemler yöntemindeki final matris çözümünün tersini alma işlemi gözlem sayısı ve değişken sayısı çok fazla olduğunda zorlaşmaktadır.
#
# * İkinci yöntemimiz ise optimizasyon yöntemi/çözümüdür. Diğer adı gradient descent'tir.
#
# * ![image-5.png](attachment:image-5.png)
#
# * DİKKAT : Nereden geldik buraya hızlı bir şekilde toparlayalım. Hatamızın minumum olmasını istiyoruz. Bunun da ağırlıklara bağlı olduğunu gördük. Dolayısıyla bu ağırlıkları bulmak önemli bir iştir. Bu ağırlıkları nasıl buluruz ki diye sorduğumuzda karşımıza 2 yöntem çıktı. Birincisi az önce gördüğümüz normal denklemler yöntemiyken, ikincisi gradient descent yöntemidir.
#
# ###### Gradient Descent Nasıl Çalışır?
# * Parametrelerin değerlerini iteratif bir şekilde değiştirerek çalışır.
#
# * DİKKAT : Bir diğer notasyon...
# * teta 0 sabit/bias yani b0'dır. teta 1 ifadesi ise b1 yani w'dir. Karşımıza farklı şekillerde çıkabilir.
#
# * ![image-6.png](attachment:image-6.png)
#
# * DİKKAT : Buradaki değerler bu ağırlıkların eski değerleri bu eski değerler yeniden atanarak güncelleniyor bilgisi var burada.
