# %% [markdown]
# ### Ağırlıkların Bulunması
#
# * Önceki bölümde w değerlerine göre değişkenlerin etkileri biçimlendirilebiliyor dedik. Peki bu ağırlıkları nasıl bulacağız?
#
# * ![image.png](attachment:image.png)
#
# * Yukarıdaki denklemdeki b ve w ifadesi öyle bir bulunmalı ki bunlar en uygun değerlere sahip olsun. Peki bu iki ifadeyi nasıl bulacağız?
#
# * ![image-2.png](attachment:image-2.png)
#
# * metrekare ve fiyat arasında doğrusal bir ilişki olduğunu düşünüyoruz ve bunu aşağıdaki gibi modelliyoruz.
#
# * ![image-3.png](attachment:image-3.png)
#
# * Görüldüğü üzere ilişki görselleştirilmiş. Bu iki ifade arasındaki ilişkiyi doğrusallaştırabilirsek bazı metrekare bilgilerini fonksiyona sokarak ev fiyatı bilgilerinin ne olacağını öğrenebiliriz.
#
# * ![image-4.png](attachment:image-4.png)
#
# * Yukarıdaki fonksiyon kullanılarak sabit ve ağırlığa göre tahminlerde bulunma imkanı yakalıyor olacağız. Model dediğimiz şey aslında bu kırmızı doğrudur. Ağırlık (w) ve sabitten (b) oluşmaktadır.
#
# * ![image-5.png](attachment:image-5.png)
#
# * Bu doğruyu nasıl koyacağız sorusu ile b ve w değerleri ne olmalı sorusu aynı sorudur. Yukarıda görüldüğü gibi doğru birçok şekilde çizilebilir ancak en uygun doğruyu bulmak asıl meseledir. Bunun matematiksel yolu şudur:
#
# * ![image-7.png](attachment:image-7.png)
#
# * Aslında bu MSE fonksiyonudur.
#
# * ![image-8.png](attachment:image-8.png)
# * 210 + 4 * 90 = 570 bu işlemin sonucu y şapkayı yani tahmin edilen ev fiyatını verecektir.
#
# * ![image-9.png](attachment:image-9.png)
# * 120 + 3 * 90 = 390 'dır.
#
# * Şimdi soru şu aynı metrekare için farklı fiyatlar aldık. Neden? Çünkü ağırlık değerlerimiz farklıydı. Anlaşılıyor ki ağırlıklar ve sabit değiştiğinde fiyatlar değişiyor. Fiyatlar değişiyorsa hatalar da değişmiş olacaktır. Dolayısıyla bu iki değerin denenmesi neticesinde farklı tahminler ve farklı ortalama tahmin hataları elde ediyoruz.
#
# * ![image-10.png](attachment:image-10.png)
# * Diyelim ki tüm b ve w değerleri için yi = b + wxi hesabını yaptık. Öyleyse aşağıdaki tablodaki hatalarımıza bakalım:
#
# * ![image-11.png](attachment:image-11.png)
# * Htalara baktığımızda bazı hesaplamalarda iyiyken bazılarında çok kötü olduğumuzu görüyoruz. Yani başarılı tahminler varken başarısız tahminler de var.
