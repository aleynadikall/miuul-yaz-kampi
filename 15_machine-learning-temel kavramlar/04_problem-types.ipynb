# %% [markdown]
# ### Problem Türleri (Problem Types)
#
# * ![image.png](attachment:image.png)
#
# * ![image-2.png](attachment:image-2.png)
#
# * DİKKAT : Churn' e YES, NO yazmak yerine bunları encode ederek 1, 0 olarak yazdırmışız çünkü algoritmalar bunu bizden numerik formatta ister.
